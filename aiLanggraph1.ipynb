# %% [markdown]
# <a href="https://colab.research.google.com/github/utsabdangol/machine_learing_python/blob/main/aiLanggraph1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install required libraries (for Jupyter/Colab)
# !pip install langgraph langchain python-dotenv transformers torch

# Python standard imports
from typing import TypedDict, List, Literal

# LangChain core message import (note: plural 'messages')
from langchain_core.messages import HumanMessage

# LangGraph imports for building state graphs
from langgraph.graph import StateGraph, START, END

# Load environment variables from a .env file if available
from dotenv import load_dotenv
load_dotenv()
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.9/143.9 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 94.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 70.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 56.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.8 MB/s eta 0:00:00
# ...

# %%
# Hugging Face model pipeline setup
# !pip install langchain-community
from transformers import pipeline
from langchain_community.llms import HuggingFacePipeline

# Load a small, free text model (no API key needed)
hf_generator = pipeline("text2text-generation", model="google/flan-t5-large", max_length=100)

# Create an LLM instance compatible with LangChain
llm = HuggingFacePipeline(pipeline=hf_generator)

# Example state definition
class AgentState(TypedDict):
    messages: List[HumanMessage]
# Out:
# ...
# config.json:   0%|          | 0.00/662 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/3.13G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/147 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
def process(state: AgentState) -> AgentState:
    input_text = state["messages"][0].content
    prompt = f"You are a helpful assistant. Answer the question clearly:\n{input_text}"
    response = llm.invoke(prompt)
    print(f"\nAI: {response}")
    return state

graph = StateGraph(AgentState)
graph.add_node("process",process)
graph.add_edge(START, "process")
graph.add_edge("process", END)

app=graph.compile()

# %%
user_input=input("Enter: ")
app.invoke({"messages": [HumanMessage(content=user_input)]})
# Out:
# Enter: step by step guide for making an egg
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-545666608.py in <cell line: 0>()
#       1 user_input=input("Enter: ")
# ----> 2 app.invoke({"messages": [HumanMessage(content=user_input)]})
#
# NameError: name 'app' is not defined
